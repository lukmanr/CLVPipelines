# %%
import sys

# !{sys.executable} -m pip install google-cloud-bigquery
# Out:
# Collecting google-cloud-bigquery
#   Downloading https://files.pythonhosted.org/packages/b3/33/236bdc6f5204bed8f69aecbabbe1a9b3a5be51f959fb51eba0545181ffa0/google_cloud_bigquery-1.11.2-py2.py3-none-any.whl (127kB)
#      |████████████████████████████████| 133kB 5.0MB/s
# Requirement already satisfied: protobuf>=3.6.0 in /home/jupyter/kfp/lib/python3.5/site-packages (from google-cloud-bigquery) (3.7.1)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.6.0 in /home/jupyter/kfp/lib/python3.5/site-packages (from google-cloud-bigquery) (1.9.0)
# Requirement already satisfied: google-resumable-media>=0.3.1 in /home/jupyter/kfp/lib/python3.5/site-packages (from google-cloud-bigquery) (0.3.2)
# Requirement already satisfied: google-cloud-core<0.30dev,>=0.29.0 in /home/jupyter/kfp/lib/python3.5/site-packages (from google-cloud-bigquery) (0.29.1)
# Requirement already satisfied: setuptools in /home/jupyter/kfp/lib/python3.5/site-packages (from protobuf>=3.6.0->google-cloud-bigquery) (41.0.1)
# Requirement already satisfied: six>=1.9 in /home/jupyter/kfp/lib/python3.5/site-packages (from protobuf>=3.6.0->google-cloud-bigquery) (1.12.0)
# Requirement already satisfied: googleapis-common-protos!=1.5.4,<2.0dev,>=1.5.3 in /home/jupyter/kfp/lib/python3.5/site-packages (from google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (1.5.9)
# Requirement already satisfied: google-auth<2.0dev,>=0.4.0 in /home/jupyter/kfp/lib/python3.5/site-packages (from google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (1.6.3)
# Requirement already satisfied: pytz in /home/jupyter/kfp/lib/python3.5/site-packages (from google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (2019.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /home/jupyter/kfp/lib/python3.5/site-packages (from google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (2.21.0)
# Requirement already satisfied: rsa>=3.1.4 in /home/jupyter/kfp/lib/python3.5/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jupyter/kfp/lib/python3.5/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (0.2.5)
# Requirement already satisfied: cachetools>=2.0.0 in /home/jupyter/kfp/lib/python3.5/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (3.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyter/kfp/lib/python3.5/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter/kfp/lib/python3.5/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/jupyter/kfp/lib/python3.5/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/jupyter/kfp/lib/python3.5/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (1.24.2)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/jupyter/kfp/lib/python3.5/site-packages (from rsa>=3.1.4->google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.6.0->google-cloud-bigquery) (0.4.5)
# Installing collected packages: google-cloud-bigquery
# Successfully installed google-cloud-bigquery-1.11.2

# %%
from google.cloud import bigquery

client = bigquery.Client()

# Perform a query.
QUERY = (
    'SELECT name FROM `bigquery-public-data.usa_names.usa_1910_2013` '
    'WHERE state = "TX" '
    'LIMIT 100')
query_job = client.query(QUERY)  # API request
rows = query_job.result()  # Waits for query to finish

for row in rows:
    print(row.name)
# Out:
# Frances
# Alice
# Beatrice
# Ella
# Gertrude
# Josephine
# Lula
# Blanche
# Marjorie
# Christine
# Margarita
# Alta
# Sara
# Naomi
# Sofia
# Andrea
# Delfina
# Dominga
# Elnora
# Adele
# Rafaela
# Dixie
# Luisa
# Bess
# Ernestine
# Lorine
# Patsy
# Cecelia
# Enriqueta
# Lucinda
# Alyce
# Oneta
# Apolonia
# Gloria
# Rhoda
# Buna
# Maye
# Pansy
# Gladys
# Maria
# Helen
# Velma
# Clara
# Anna
# Evelyn
# Rosa
# Mae
# Bernice
# Stella
# Vivian
# Mable
# Maggie
# Betty
# Guadalupe
# Lorene
# Susie
# Sadie
# Erma
# Verna
# Amelia
# Estelle
# Nell
# Margie
# Celia
# Lessie
# Eloise
# Millie
# Olga
# Letha
# Rachel
# Luz
# Gussie
# Sylvia
# Aline
# Barbara
# Iris
# Leila
# Mozelle
# Simona
# Catalina
# Hester
# Willia
# Allene
# Avis
# George
# Isabella
# Polly
# Syble
# Teodora
# Lennie
# Ricarda
# Valerie
# Robert
# Willie
# Fred
# Raymond
# Richard
# Sam
# Ernest
# Leroy

# %%
# from google.cloud import bigquery
# client = bigquery.Client()

job_config = bigquery.QueryJobConfig()
job_config.dry_run = True
job_config.use_query_cache = False
query_job = client.query(
    (
        "SELECT name, COUNT(*) as name_count "
        "FROM `bigquery-public-data.usa_names.usa_1910_2013` "
        "WHERE state = 'WA' "
        "GROUP BY name"
    ),
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
    job_config=job_config,
)  # API request

# A dry run query completes immediately.
assert query_job.state == "DONE"
assert query_job.dry_run

print("This query will process {} bytes.".format(query_job.total_bytes_processed))
# Out:
# This query will process 65935918 bytes.
